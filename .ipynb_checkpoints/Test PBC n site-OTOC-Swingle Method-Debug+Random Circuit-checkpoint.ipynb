# %%
from tqdm import tqdm
from qiskit import quantum_info
from qiskit.quantum_info import DensityMatrix, Statevector, partial_trace
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
import numpy as np
#from qiskit_experiments.framework import ParallelExperiment
from qiskit_experiments.library import StateTomography
from qiskit.providers.aer import AerSimulator
from qiskit.providers.fake_provider import FakeParis
from numpy.linalg import norm 
import cvxpy
#set noisy simulator backend 
#backend = AerSimulator.from_backend(FakeParis())
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Operator
from qiskit.transpiler import PassManager
from qiskit.transpiler.passes import Unroller
#visualization
from qiskit.visualization import plot_state_city
from qiskit.visualization import plot_histogram
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit import Parameter
from qiskit.primitives import Estimator
from qiskit_ibm_runtime import Estimator, Session, QiskitRuntimeService, Options, Sampler
from qiskit.visualization import array_to_latex
from qiskit.extensions import UnitaryGate

# %%
mat=U(1,1,1)
uni = mat.conj().T@mat
np.allclose(np.eye(4),uni,atol=1e-15)
# Out:
# True

# %%
dispcolors = {'cx':('#426299', '#000000'),
              'cswap':('#705399', '#000000'),
              'cp':('#CFFF8B', '#000000')}

# %%
# Save an IBM Quantum account.
QiskitRuntimeService.save_account(channel="ibm_quantum", token="b58a80862cd6d4e3f8618d0fb10c85a7415315bcf55dd407e498ce33bdd4709623e266b4fdee952700733135cd2fa847c7bffa65966a4efb0aa2ae6a4ad7b583", overwrite=True)

# %%
#MAIN (TROTTER EVO)

#parameters
n,A,T,G,step=6,1,1,0,10
time = 4
layers = np.array([j for j in range(1,step)])
C = np.zeros((n,len(layers)),dtype=float)
init='000000'


#specify the credentials when initializing QiskitRuntimeService, if they are not previously saved
service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.backend("simulator_statevector")

#settings job execution
options = Options()
options.execution.shots = 1000
options.optimization_level = 2  # optimization
options.resilience_level = 2  # mitigation

for i in tqdm(range(1,n+1)):
    for k,layer in enumerate(tqdm(layers)):
        qc=QuantumCircuit(n+1)
        #init
        #string = init
        #QuantumCircuit.initialize(qcp,string)
        X = np.array([[0,1],[1,0]])
        
        qc.h(0)
        X = np.array([[0,1],[1,0]])
        #creation of controlled unitary
        v_gate = UnitaryGate(X, label='CU') #this gate will have to be the whole evolution circuit 
        
        v_gate = v_gate.control(ctrl_state='1')
        qc.append(v_gate, [0,n//2])
        
        #fwd evolution
        qc.barrier(range(n+1))
        qc.barrier(range(n+1))
        matrix = U(A,T/step,G)
        bwassembler_1(qc,matrix,layer,n)
        #W_j perturbation
        qc.z(i)
        #backwards evolution
        qc.barrier(range(n+1))
        qc.barrier(range(n+1))
        revbwassembler_1(qc,matrix,layer,n)
        qc.append(v_gate, [0,n//2])

        #generate operator to measure
        op=generate_pauli_1(n,n//2)
        #runtime
        with Session(service=service, backend=backend) as session:
            estimator_sim = Estimator(session=session, options=options)
            job_sim = estimator_sim.run(circuits=[qc], observables=[op])
            values = job_sim.result().values
        
        C[i,k]=values
# Out:
#   0%|                                                                                             | 0/6 [00:00<?, ?it/s]
#   0%|                                                                                             | 0/9 [00:00<?, ?it/s]
#  11%|█████████▍                                                                           | 1/9 [00:07<00:58,  7.35s/it]
#   0%|                                                                                             | 0/6 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[86], line 56
#      54     estimator_sim = Estimator(session=session, options=options)
#      55     job_sim = estimator_sim.run(circuits=[qc], observables=[op])
# ---> 56     values = job_sim.result().values
#      58 C[i,k]=values
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:217, in RuntimeJob.result(self, timeout, decoder)
#     215 _decoder = decoder or self._final_result_decoder
#     216 if self._results is None or (_decoder != self._final_result_decoder):
# --> 217     self.wait_for_final_state(timeout=timeout)
#     218     if self._status == JobStatus.ERROR:
#     219         error_message = self._reason if self._reason else self._error_message
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:309, in RuntimeJob.wait_for_final_state(self, timeout)
#     306     self._ws_client_future.result(timeout)
#     307 # poll for status after stream has closed until status is final
#     308 # because status doesn't become final as soon as stream closes
# --> 309 status = self.status()
#     310 while status not in JOB_FINAL_STATES:
#     311     elapsed_time = time.time() - start_time
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:274, in RuntimeJob.status(self)
#     268 def status(self) -> JobStatus:
#     269     """Return the status of the job.
#     270
#     271     Returns:
#     272         Status of this job.
#     273     """
# --> 274     self._set_status_and_error_message()
#     275     return self._status
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:440, in RuntimeJob._set_status_and_error_message(self)
#     438 """Fetch and set status and error message."""
#     439 if self._status not in JOB_FINAL_STATES:
# --> 440     response = self._api_client.job_get(job_id=self.job_id())
#     441     self._set_status(response)
#     442     self._set_error_message(response)
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/api/clients/runtime.py:218, in RuntimeClient.job_get(self, job_id, exclude_params)
#     209 def job_get(self, job_id: str, exclude_params: bool = None) -> Dict:
#     210     """Get job data.
#     211
#     212     Args:
#    (...)
#     216         JSON response.
#     217     """
# --> 218     response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     219     logger.debug("Runtime job get response: %s", response)
#     220     return response
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_provider/api/rest/program_job.py:62, in ProgramJob.get(self, exclude_params)
#      60 if exclude_params:
#      61     payload["exclude_params"] = "true"
# ---> 62 return self.session.get(self.get_url("self"), params=payload).json(
#      63     cls=RuntimeDecoder
#      64 )
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/qiskit_ibm_runtime/api/session.py:345, in RetrySession.request(self, method, url, bare, **kwargs)
#     343 try:
#     344     self._log_request_info(final_url, method, kwargs)
# --> 345     response = super().request(method, final_url, headers=headers, **kwargs)
#     346     response.raise_for_status()
#     347 except RequestException as ex:
#     348     # Wrap the requests exceptions into a IBM Q custom one, for
#     349     # compatibility.
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/qusim/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/qusim/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/qusim/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/qusim/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/qusim/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/envs/qusim/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/qusim/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
Cnew=np.flipud(np.transpose(C))
plt.imshow(Cnew)
plt.xlabel('Sites')
plt.ylabel('Time')
#plt.title('A='+str(A)+' T='+str(T)+' G='+str(G)+' size='+str(n)+' init='+str(init)+' step='+str(step))
plt.colorbar()

# %%
#MAIN 2 THE ONE THAT IS GONNA WORK (THETA SWEEP)
#theta0*layers=t
#parameters
n,A,T,G,step=6,1,1,0,1
times = [j for j in range(1,5)]
theta0=0.01
thetas= np.arange(0.001,2,0.2)
C = np.zeros((n,len(thetas)),dtype=float)
init='000000'

#specify the credentials when initializing QiskitRuntimeService, if they are not previously saved
service = QiskitRuntimeService(channel="ibm_quantum")
backend = service.backend("simulator_statevector")

#settings job execution
options = Options()
options.execution.shots = 1000
options.optimization_level = 1  # optimization
options.resilience_level = 2  # mitigation

for i in tqdm(range(1,n+1)):
    for k,t in enumerate(tqdm(thetas)):
        qc=QuantumCircuit(n+1)
        #init
        #string = init
        #QuantumCircuit.initialize(qcp,string)
        X = np.array([[0,1],[1,0]])
        
        qc.h(0)
        X = np.array([[0,1],[1,0]])
        #creation of controlled unitary
        v_gate = UnitaryGate(X, label='CU') #this gate will have to be the whole evolution circuit 
        
        v_gate = v_gate.control(ctrl_state='1')
        qc.append(v_gate, [0,n//2])
       
        #fwd evolution
        matrix = U(A,t,G)
        qc.barrier(range(n+1))
        qc.barrier(range(n+1))
        bwassembler_1(qc,matrix,1,n)
        #W_j perturbation
        qc.z(i)
        #backwards evolution
        qc.barrier(range(n+1))
        qc.barrier(range(n+1))
        revbwassembler_1(qc,matrix,1,n)
        qc.append(v_gate, [0,n//2])
        
        #generate operator to measure
        op=generate_pauli_1(n,n//2)
        #runtime
        with Session(service=service, backend=backend) as session:
            estimator_sim = Estimator(session=session, options=options)
            job_sim = estimator_sim.run(circuits=[qc], observables=[op])
            values = job_sim.result().values
        
        C[i,k]=values

# %%
Cnew=np.flipud(np.transpose(C))
plt.imshow(Cnew)
plt.xlabel('Sites')
plt.ylabel('Time')
#plt.title('A='+str(A)+' T='+str(T)+' G='+str(G)+' size='+str(n)+' init='+str(init)+' step='+str(step))
plt.colorbar()

# %%
#saving data
with open('tau='+str(tau)+' h='+str(h)+' J='+str(J)+' n='+str(n)+' init: '+str(string), 'wb') as file:
      
    # A new file will be created
    pickle.dump(ent_entropy, file)

# %%
#loading data
with open('tau='+str(tau)+' h='+str(h)+' J='+str(J)+' n=10', 'rb') as file:
    loaded_data = pickle.load(file)

# %%
#OTOC
#PLUS PART


def circ(n,A,T,G,step,layers,pos,init):
    matrix = U(A,T/step,G)
    qc=QuantumCircuit(n+1)
    #init
    #string = init
    #QuantumCircuit.initialize(qcp,string)
    X = np.array([[0,1],[1,0]])
    qc.h(0)
    
    
    
    #V_i perturbation +pi/2
    qcp.ry((np.pi/2),n//2,label='V_plus')
    #fwd evolution
    qcp.barrier(range(n))
    qcp.barrier(range(n))
    bwassembler(qcp,matrix,layers,n)
    #W_j perturbation
    qcp.z(pos)
    #backwards evolution
    qcp.barrier(range(n))
    qcp.barrier(range(n))
    revbwassembler(qcp,matrix,layers,n)
    #transpiling
    basis_gates=['cx', 'id', 'rz', 'x', 'sx']
    trans_plus=transpile(qcp, basis_gates=basis_gates, optimization_level=2)
    
    return trans_plus


#define unitary
def U(A,T,G):
    U = np.zeros((4,4), dtype=complex)
    
    U[0,0]=(-1+2*1j*A*np.cosh(G/2)*(1/np.sinh(T)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[0,3]=(1j*A*(1/np.cosh(T/2)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[1,1]=(1j*A*(1/np.sinh(T/2)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[1,2]=(-1+2*1j*A*(1/np.sinh(T))*np.sinh(G/2))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[2,1]=(-1-2*1j*A*(1/np.sinh(T))*np.sinh(G/2))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[2,2]=(1j*A*(1/np.sinh(T/2)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[3,0]=-(1j*A*(1/np.cosh(T/2)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    U[3,3]=(1+2*1j*A*np.cosh(G/2)*(1/np.sinh(T)))/np.sqrt((1+2*A**(2)*(1/np.tanh(T))*(1/np.sinh(T)))+2*A**(2)*np.cosh(G)*(1/np.sinh(T))**2)
    
    return(U)

#define BW
def bwassembler_1(qc,matrix,layers,n):
    
    m=0
    while m < layers:
        i=0;j=0;    
        #even layer
        while i < n/2:
            qc.unitary(matrix, [2*i+1,2*i+2])
            i+=1;
        qc.barrier(range(n+1))
        
        
        #odd layer
        while j < n/2:
            
            if j == (n/2 - 1):
                qc.unitary(matrix,[2*j+2,1])
            else:
                qc.unitary(matrix, [2*j+2,2*j+3])
            
            j+=1;
        qc.barrier(range(n+1))
        
        
        m+=1
    qc.barrier(range(n+1))
    return(qc)

#define reversed BW
def revbwassembler_1(qc,matrix,layers,n):
    matrix=matrix.conj().T
    m=0
    while m < layers:
        i=0;j=0;    
        
        #odd layer
        while j < n/2:
            
            if j == (n/2 - 1):
                qc.unitary(matrix,[2*j+2,1])
            else:
                qc.unitary(matrix, [2*j+2,2*j+3])
            
            j+=1;
        qc.barrier(range(n+1))
        
        #even layer
        while i < n/2:
            qc.unitary(matrix, [2*i+1,2*i+2])
            i+=1;
        qc.barrier(range(n+1))
        
        
        m+=1
    qc.barrier(range(n+1))
    return(qc)

#define operators to measure
def generate_pauli_1(n, j):
    if n <= 0 or j < 0 or  j >= n:
        raise ValueError("Invalid input values")
    
    pauli_str = "I" * (n+1)  # Initialize with n identity operators
    # Set the Z at position i and j
    pauli_str_list = list(pauli_str)
    pauli_str_list[j] = "X"
    pauli_str = "".join(pauli_str_list)
    op = SparsePauliOp(pauli_str, coeffs=[1])
    
    return op

def prodstaten(n):
    
    X = np.array([[0,1],[1,0]])
    X0 = np.zeros((n,2**n,2**n),dtype = complex)
    
    for i in range(0,n):   
        X0[i]=np.kron(np.kron(np.eye(2**i),X),np.eye(2**(n-i-1)))
    operator = np.eye(2**n)
    for i in range(0,n//2):
        operator = (X0[2*i]+1j*X0[2*i+1])@operator
    return (1/np.sqrt(2**(n//2)))*operator
    
def bell_pair1(qc, a, b):
    
    qc.h(a) # Put qubit a into state |+> or |-> using hadamard gate
    qc.cx(a,b) # CNOT with a as control and b as target
    
def bell_pair4(qc,a,b):
    
    qc.h(a)
    qc.x(b)
    qc.z(a)
    qc.z(b)
    qc.cx(a,b)

# %%
n,A,T,G,step,layers,pos=4,1,1,0,1,1,2
matrix = U(A,T/step,G)
qc=QuantumCircuit(n+1)
#init
#string = init
#QuantumCircuit.initialize(qcp,string)
X = np.array([[0,1],[1,0]])

qc.h(0)
X = np.array([[0,1],[1,0]])
#creation of controlled unitary
v_gate = UnitaryGate(X, label='CU') #this gate will have to be the whole evolution circuit 

v_gate = v_gate.control(ctrl_state='1')
qc.append(v_gate, [0,n//2])

#fwd evolution
qc.barrier(range(n+1))
qc.barrier(range(n+1))
bwassembler_1(qc,matrix,layers,n)
#W_j perturbation
qc.z(pos)
#backwards evolution
qc.barrier(range(n+1))
qc.barrier(range(n+1))
revbwassembler_1(qc,matrix,layers,n)
qc.append(v_gate, [0,n//2])

#transpiling
basis_gates=['cx', 'id', 'rz', 'x', 'sx']
#trans_plus=transpile(qc, basis_gates=basis_gates, optimization_level=2)
qc.draw(output='mpl',style={'displaycolor':dispcolors}, filename='my_circuit.pdf')

# %%
qc = QuantumCircuit(2)
X = np.array([[0,1],[1,0]])
#creation of controlled unitary
cu_gate = UnitaryGate(X, label='CU') #this gate will have to be the whole evolution circuit 

anti_gate = cu_gate.control(ctrl_state='1')
qc.append(anti_gate, [0,1])
dispcolors = {'cx':('#426299', '#000000'),
              'cswap':('#705399', '#000000'),
              'cp':('#CFFF8B', '#000000')}
qc.draw(output='mpl',style={'displaycolor':dispcolors}, filename='my_circuit.pdf')

# %%
generate_pauli_1(5,2)
# Out:
# SparsePauliOp(['IIIXII'],
#               coeffs=[1.+0.j])

# %%
qc=QuantumCircuit(n+1)
#init
#string = init
#QuantumCircuit.initialize(qcp,string)
X = np.array([[0,1],[1,0]])

qc.h(0)
X = np.array([[0,1],[1,0]])
#creation of controlled unitary
v_gate = UnitaryGate(X, label='CU') #this gate will have to be the whole evolution circuit 

v_gate = v_gate.control(ctrl_state='1')
qc.append(v_gate, [0,n//2])

#fwd evolution
matrix = U(A,t,G)
qc.barrier(range(n+1))
qc.barrier(range(n+1))
bwassembler_1(qc,matrix,1,n)
#W_j perturbation
qc.z(1)
#backwards evolution
qc.barrier(range(n+1))
qc.barrier(range(n+1))
revbwassembler_1(qc,matrix,1,n)
qc.append(v_gate, [0,n//2])

qc.draw(output='mpl',style={'displaycolor':dispcolors}, filename='my_circuit.pdf')

# %%
generate_pauli_1(6,3)
# Out:
# SparsePauliOp(['IIIXIII'],
#               coeffs=[1.+0.j])
